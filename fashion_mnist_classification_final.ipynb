# %%
from tensorflow.keras.datasets import fashion_mnist
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt

# %%
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# Flatten images
X_train = train_images.reshape(len(train_images), -1)
X_test = test_images.reshape(len(test_images), -1)
knn = KNeighborsClassifier(n_neighbors=4)
y_pred = knn.fit(X_train, train_labels).predict(X_test)
print("Number of mislabeled points out of a total %d points : %d. Accuracy : %f" % (X_test.shape[0], (test_labels != y_pred).sum(), (1-(test_labels != y_pred).sum()/test_images.shape[0])*100))
# Out:
# Number of mislabeled points out of a total 10000 points : 1423. Accuracy : 85.770000

# %%
# Print accuracy
print("Number of mislabeled points out of a total %d points : %d. Accuracy : %f" % (
    test_images.shape[0],
    (test_labels != y_pred).sum(),
    (1 - (test_labels != y_pred).sum() / test_images.shape[0]) * 100
))

# Class names for Fashion-MNIST
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# Show 2 examples
for i in [0, 1]:  # first two images
    plt.imshow(test_images[i], cmap="gray")
    plt.title(f"True: {class_names[test_labels[i]]}, Pred: {class_names[y_pred[i]]}")
    plt.axis("off")
    plt.show()
# Out:
# Number of mislabeled points out of a total 10000 points : 1423. Accuracy : 85.770000
